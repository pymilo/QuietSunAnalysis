# %% [markdown]
# # Rocket height vs time for detector background studies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Defining times:
tlaunch        = 69060
t1_pos0_start  = 102.0
t1_pos0_end    = 134.3
t1_pos1_start  = 138.0
t1_pos1_end    = 162.6
t1_pos2_start  = 166.5
t1_pos2_end    = 205.0
t2_pos0_start  = 209.0
t2_pos0_end    = 219.6
t2_pos1_start  = 224.0
t2_pos1_end    = 276.7
t3_pos0_start  = 280.6
t3_pos0_end    = 307.2
t3_pos1_start  = 311.0
t3_pos1_end    = 330.1
t3_pos2_start  = 334.0
t3_pos2_end    = 369.2
t4_start       = 373.5
t_shtr_start   = 438.0
t_shtr_end     = 442.0
t4_end	       = 466.2
t5_start       = 470.5
t5_end	       = 503.2

# %%
times = [t1_pos0_start,t1_pos1_start,t1_pos2_start,
         t2_pos0_start,t2_pos1_start,t3_pos0_start,
         t3_pos1_start,t3_pos2_start,t4_start,t5_start,t5_end]

# %%
data_f2 = pd.read_csv("./FOXSI-2 Flight Profile.csv")

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(data_f2["TIME"].values,data_f2["ALT.(M)"].values/1000)
ax.vlines(times,ymin=0,ymax=360,color='grey',linestyles='dashed')
ax.vlines(t_shtr_start,ymin=0,ymax=360,color='tab:red',linestyles='dashed')
ax.axvspan(t1_pos0_start, t1_pos2_end, alpha=0.2, color='tab:blue')
ax.axvspan(t2_pos0_start, t2_pos1_end, alpha=0.2, color='tab:orange')
ax.axvspan(t3_pos0_start, t3_pos2_end, alpha=0.2, color='tab:green')
ax.axvspan(t4_start, t4_end, alpha=0.2, color='tab:red')
ax.axvspan(t5_start, t5_end, alpha=0.2, color='grey')
# ornaments
ax.set_ylim(0,360)
ax.set_xlim(0,700)
ax.set_xlabel('Time [s]',fontsize=28)
ax.set_ylabel('Altitud [km]',fontsize=28)
ax.tick_params(axis='both', labelsize=20)
ax.set_title('FOXSI2 flight',fontsize=28)
# Out:
# Text(0.5, 1.0, 'FOXSI2 flight')

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(data_f2["TIME"].values,data_f2["ALT.(M)"].values/1000)
ax.vlines(300,ymin=0,ymax=360,color='grey',linestyles='dashed')
ax.hlines(340,xmin=0,xmax=700,color='grey',linestyles='dashed')
# ornaments
ax.set_ylim(0,360)
ax.set_xlim(0,700)
ax.set_xlabel('Time [s]',fontsize=28)
ax.set_ylabel('Altitud [km]',fontsize=28)
ax.tick_params(axis='both', labelsize=20)
ax.set_title('FOXSI2 flight',fontsize=28)
# Out:
# Text(0.5, 1.0, 'FOXSI2 flight')
